# %%
## History of NLP :
1950-1980  : Rule Based
1980-2000 : Statistical & ML
1987      : RNN
1997      : LSTM

## 2010s :
>> GPU :
>> Data :

2013 --> AlexNet (CV)

# %%
2013  --> Word2Vec

# %%
## Types of RNN :
one to one  :
one to many  :
many to one  :
many to many : Machine Translation

# %%
# Machine Translation : Seq2Seq

2014  : Encoder-Decoder - Google (Illy Sustskevar)
2015  : Attention Mechanism

2017 : Attention is all you need (Transformer) : Google

2018 : ULMFit (Universal Language Model Fine-tuning) - Jeremy Howard
       Language Modeling :

2018 : GPT (Generative Pretrained Transformer)
2018 : BERT (Bidirectional Encoder Representations from Transformers)

Nov 2022 : ChatGPT (GPT-3.5)
